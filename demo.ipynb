# %%
from src.compute_routines.scale_filter_functions import *
from src.compute_routines.compute_PiD_functions import *

# %%
data = '/home/sroy/Documents/IWF_research/MMS_events/MSH Reconnection/20151209_050300_20151209_050400.h5'

PiDi = compute_PiD(data)
# Out:
# Ptensor_ion_1_reselectron
# Ptensor_ion_2_reselectron
# Ptensor_ion_3_reselectron
# Ptensor_ion_4_reselectron
# Ptensor_ion_1_reselectron
# Ptensor_ion_2_reselectron
# Ptensor_ion_3_reselectron
# Ptensor_ion_4_reselectron
# N_elc_1
# N_elc_2
# N_elc_3
# N_elc_4
# N_ion_1
# N_ion_1_reselectron
# N_ion_2
# N_ion_2_reselectron
# N_ion_3
# N_ion_3_reselectron
# N_ion_4
# N_ion_4_reselectron
# Ptensor_elc_1
# Ptensor_elc_2
# Ptensor_elc_3
# Ptensor_elc_4
# Ptensor_ion_1
# Ptensor_ion_1_reselectron
# Ptensor_ion_2
# Ptensor_ion_2_reselectron
# Ptensor_ion_3
# Ptensor_ion_3_reselectron
# Ptensor_ion_4
# Ptensor_ion_4_reselectron
# Temptensor_elc_1
# Temptensor_elc_2
# Temptensor_elc_3
# Temptensor_elc_4
# Temptensor_ion_1
# Temptensor_ion_1_reselectron
# Temptensor_ion_2
# Temptensor_ion_2_reselectron
# Temptensor_ion_3
# Temptensor_ion_3_reselectron
# Temptensor_ion_4
# Temptensor_ion_4_reselectron
# b_gse_1
# b_gse_2
# b_gse_3
# b_gse_4
# edp_dce_gse_1
# edp_dce_gse_2
# edp_dce_gse_3
# ...

# %%
PiDi
# Out:
#                                 PiD_ion
# Epoch
# 2015-12-09 05:03:00.007123950  0.080248
# 2015-12-09 05:03:00.037137867  0.078467
# 2015-12-09 05:03:00.067151784  0.071824
# 2015-12-09 05:03:00.097125474  0.065196
# 2015-12-09 05:03:00.127139391  0.058563
# ...                                 ...
# 2015-12-09 05:03:59.857614043 -0.039461
# 2015-12-09 05:03:59.887627960 -0.045915
# 2015-12-09 05:03:59.917601640 -0.040604
# 2015-12-09 05:03:59.947615566 -0.035246
# 2015-12-09 05:03:59.977629483 -0.029848
#
# [2000 rows x 1 columns]
